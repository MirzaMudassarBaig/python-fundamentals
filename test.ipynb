# %% [markdown]
#  **subject of this notebook:**\
#  authored by : sana\
#  where to contact: github profile link or email (gmail) google colab link\
# [lecture5](https://www.youtube.com/watch?v=V5Pk5qvRo7A&t=523s)

# %% [markdown]
# code ko separate krna k liya ipynb file banti hy

# %%
#code1
print("sana")
6+6
# Out:
# sana
# 12

# %%
#code2
name=input("what is your name?")

# %%
#code3
print("hello",name)
# Out:
# hello sana

# %%
fruit_basket="mangoes"
fruit_basket
(type(fruit_basket))
# Out:
# str

# %%
fruit_basket
# Out:
# 'mangoes'

# %% [markdown]
# [how to convert jupiter notebook to pdf?]  # assignment

# %%
student=("ali","ahmed","iqra","ayesha")
student
# Out:
# ('ali', 'ahmed', 'iqra', 'ayesha')

# %%
age=20
new_age= 20+age

# %%
new_age
# Out:
# 40

# %%
x=3*4
x
# Out:
# 12

# %%
x=("we are learning python")
x
# Out:
# 'we are learning python'
